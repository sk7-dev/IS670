# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
file = "Datasets/pandas_etl.csv"

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00

# %%
df.tail()
# Out:
#     TransactionID  CustomerID                Item     Category  \
# 16              7         107      Book - Fiction        Books
# 17              7         107  Book - Non-Fiction        Books
# 18              7         107             Journal   Stationery
# 19              8         108          Phone Case  Electronics
# 20              8         108      Travel Adapter  Electronics
#
#       PurchaseTimestamp
# 16  2025-01-07 20:15:00
# 17  2025-01-07 20:20:00
# 18  2025-01-07 20:25:00
# 19  2025-01-08 14:50:00
# 20  2025-01-08 14:55:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      21 non-null     int64
#  1   CustomerID         21 non-null     int64
#  2   Item               21 non-null     object
#  3   Category           21 non-null     object
#  4   PurchaseTimestamp  21 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 972.0+ bytes

# %%
df.describe()
# Out:
#        TransactionID  CustomerID
# count      21.000000   21.000000
# mean        4.380952  104.380952
# std         2.355338    2.355338
# min         1.000000  101.000000
# 25%         2.000000  102.000000
# 50%         4.000000  104.000000
# 75%         6.000000  106.000000
# max         8.000000  108.000000

# %%
df['CustomerID'].head()
# Out:
# 0    101
# 1    101
# 2    101
# 3    102
# 4    102
# Name: CustomerID, dtype: int64

# %%
list_of_cols = ['CustomerID', 'Item']
df[list_of_cols].head(3)
# Out:
#    CustomerID              Item
# 0         101        Phone Case
# 1         101  Screen Protector
# 2         101  Wireless Charger

# %%
df.iloc[0]
# Out:
# TransactionID                          1
# CustomerID                           101
# Item                          Phone Case
# Category                     Electronics
# PurchaseTimestamp    2025-01-01 10:05:00
# Name: 0, dtype: object

# %%
df.iloc[:5]
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00

# %%
df.iloc[0:3, 3]
# Out:
# 0    Electronics
# 1    Electronics
# 2    Electronics
# Name: Category, dtype: object

# %%
df.loc[5:, 'Category']
# Out:
# 5         Fitness
# 6     Electronics
# 7     Electronics
# 8     Electronics
# 9     Electronics
# 10    Electronics
# 11        Fitness
# 12        Fitness
# 13        Kitchen
# 14        Grocery
# 15        Kitchen
# 16          Books
# 17          Books
# 18     Stationery
# 19    Electronics
# 20    Electronics
# Name: Category, dtype: object

# %%
df.loc[5:, ['Category', 'Item']]
# Out:
#        Category                Item
# 5       Fitness      Protein Powder
# 6   Electronics          Phone Case
# 7   Electronics          Headphones
# 8   Electronics    Wireless Charger
# 9   Electronics    Portable Speaker
# 10  Electronics      Travel Adapter
# 11      Fitness            Yoga Mat
# 12      Fitness    Resistance Bands
# 13      Kitchen        Coffee Maker
# 14      Grocery        Coffee Beans
# 15      Kitchen                 Mug
# 16        Books      Book - Fiction
# 17        Books  Book - Non-Fiction
# 18   Stationery             Journal
# 19  Electronics          Phone Case
# 20  Electronics      Travel Adapter

# %%
df[df['Category'] == 'Fitness']
# Out:
#     TransactionID  CustomerID              Item Category    PurchaseTimestamp
# 3               2         102          Yoga Mat  Fitness  2025-01-02 15:20:00
# 4               2         102      Water Bottle  Fitness  2025-01-02 15:25:00
# 5               2         102    Protein Powder  Fitness  2025-01-02 15:30:00
# 11              5         105          Yoga Mat  Fitness  2025-01-05 08:30:00
# 12              5         105  Resistance Bands  Fitness  2025-01-05 08:35:00

# %% [markdown]
# FILTER

# %%
df[(df['CustomerID'] == 102) & (df['Category'] == 'Fitness')]
# Out:
#    TransactionID  CustomerID            Item Category    PurchaseTimestamp
# 3              2         102        Yoga Mat  Fitness  2025-01-02 15:20:00
# 4              2         102    Water Bottle  Fitness  2025-01-02 15:25:00
# 5              2         102  Protein Powder  Fitness  2025-01-02 15:30:00

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00

# %%
df['Store'] = 'Amazon'

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp   Store
# 0  2025-01-01 10:05:00  Amazon
# 1  2025-01-01 10:07:00  Amazon
# 2  2025-01-01 10:10:00  Amazon
# 3  2025-01-02 15:20:00  Amazon
# 4  2025-01-02 15:25:00  Amazon

# %%
df['test'] = [ x for x in range(1 , len(df) + 1) ]

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp   Store  test
# 0  2025-01-01 10:05:00  Amazon     1
# 1  2025-01-01 10:07:00  Amazon     2
# 2  2025-01-01 10:10:00  Amazon     3
# 3  2025-01-02 15:20:00  Amazon     4
# 4  2025-01-02 15:25:00  Amazon     5

# %%
df['jib'] = df['Store'] + df['Item']

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp   Store  test                     jib
# 0  2025-01-01 10:05:00  Amazon     1        AmazonPhone Case
# 1  2025-01-01 10:07:00  Amazon     2  AmazonScreen Protector
# 2  2025-01-01 10:10:00  Amazon     3  AmazonWireless Charger
# 3  2025-01-02 15:20:00  Amazon     4          AmazonYoga Mat
# 4  2025-01-02 15:25:00  Amazon     5      AmazonWater Bottle

# %%
df['Item'].iloc[1]
# Out:
# 'Screen Protector'

# %%
df.iloc[1 ,2]
# Out:
# 'Screen Protector'

# %%
df.loc[1, 'Item'] = '🐱‍💻'

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp   Store  test                     jib
# 0  2025-01-01 10:05:00  Amazon     1        AmazonPhone Case
# 1  2025-01-01 10:07:00  Amazon     2  AmazonScreen Protector
# 2  2025-01-01 10:10:00  Amazon     3  AmazonWireless Charger
# 3  2025-01-02 15:20:00  Amazon     4          AmazonYoga Mat
# 4  2025-01-02 15:25:00  Amazon     5      AmazonWater Bottle

# %%
df.loc[5:18, 'Category'] = '🦔'
df.loc[5:18, 'Store'] = '🐇'

# %%
df.head(20)
# Out:
#     TransactionID  CustomerID                Item     Category  \
# 0               1         101          Phone Case  Electronics
# 1               1         101    Screen Protector  Electronics
# 2               1         101    Wireless Charger  Electronics
# 3               2         102            Yoga Mat      Fitness
# 4               2         102        Water Bottle      Fitness
# 5               2         102      Protein Powder            🦔
# 6               3         103          Phone Case            🦔
# 7               3         103          Headphones            🦔
# 8               4         104    Wireless Charger            🦔
# 9               4         104    Portable Speaker            🦔
# 10              4         104      Travel Adapter            🦔
# 11              5         105            Yoga Mat            🦔
# 12              5         105    Resistance Bands            🦔
# 13              6         106        Coffee Maker            🦔
# ...

# %%
df = df.drop('jib', axis = 1)

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp   Store  test
# 0  2025-01-01 10:05:00  Amazon     1
# 1  2025-01-01 10:07:00  Amazon     2
# 2  2025-01-01 10:10:00  Amazon     3
# 3  2025-01-02 15:20:00  Amazon     4
# 4  2025-01-02 15:25:00  Amazon     5

# %%
df = df[['CustomerID']]

# %%
df.groupby(['Category']).sum()
# Out:
#              TransactionID  CustomerID  \
# Category
# Electronics             19         519
# Fitness                  4         204
# 🦔                       69        1469
#
#                                                           Item  \
# Category
# Electronics  Phone CaseScreen ProtectorWireless ChargerPhon...
# Fitness                                   Yoga MatWater Bottle
# 🦔            Protein PowderPhone CaseHeadphonesWireless Cha...
#
#                                              PurchaseTimestamp  \
# Category
# Electronics  2025-01-01 10:05:002025-01-01 10:07:002025-01-...
# Fitness                 2025-01-02 15:20:002025-01-02 15:25:00
# 🦔            2025-01-02 15:30:002025-01-03 09:10:002025-01-...
#
#                                       Store  test
# Category
# Electronics  AmazonAmazonAmazonAmazonAmazon    47
# Fitness                        AmazonAmazon     9
# 🦔                            🐇🐇🐇🐇🐇🐇🐇🐇🐇🐇🐇🐇🐇🐇   175

# %%
import random

[random.randint(20, 300) for _ in range(len(df))]
# Out:
# [179,
#  231,
#  277,
#  194,
#  48,
#  277,
#  33,
#  284,
#  242,
#  261,
#  142,
#  144,
#  81,
#  128,
#  84,
#  101,
#  100,
#  151,
#  293,
#  119,
#  158]

# %%
df['Cost'] = [random.randint(20, 300) for _ in range(len(df))]

# %%
df.head(20)
# Out:
#     TransactionID  CustomerID                Item     Category  \
# 0               1         101          Phone Case  Electronics
# 1               1         101    Screen Protector  Electronics
# 2               1         101    Wireless Charger  Electronics
# 3               2         102            Yoga Mat      Fitness
# 4               2         102        Water Bottle      Fitness
# 5               2         102      Protein Powder      Fitness
# 6               3         103          Phone Case  Electronics
# 7               3         103          Headphones  Electronics
# 8               4         104    Wireless Charger  Electronics
# 9               4         104    Portable Speaker  Electronics
# 10              4         104      Travel Adapter  Electronics
# 11              5         105            Yoga Mat      Fitness
# 12              5         105    Resistance Bands      Fitness
# 13              6         106        Coffee Maker      Kitchen
# ...

# %%
df_cost = df.groupby(['Category']).sum()[['Cost']].reset_index()
# Out:
#       Category  Cost
# 0        Books   278
# 1  Electronics  1901
# 2      Fitness   763
# 3      Grocery   120
# 4      Kitchen   564
# 5   Stationery   117

# %%
df.groupby(['CustomerID', 'Category']).agg(
    Sum_of_Cost = ('Cost', 'sum'),
    total_item_count = ('Item', 'count'),
    function_time = ('Cost', lambda x: x.sum() **2),
    function_time2 = ('Item', lambda x: list(x))
).reset_index()
# Out:
#    CustomerID     Category  Sum_of_Cost  total_item_count  function_time  \
# 0         101  Electronics          659                 3         434281
# 1         102      Fitness          344                 3         118336
# 2         103  Electronics          476                 2         226576
# 3         104  Electronics          485                 3         235225
# 4         105      Fitness          419                 2         175561
# 5         106      Grocery          120                 1          14400
# 6         106      Kitchen          564                 2         318096
# 7         107        Books          278                 2          77284
# 8         107   Stationery          117                 1          13689
# 9         108  Electronics          281                 2          78961
#
#                                       function_time2
# 0   [Phone Case, Screen Protector, Wireless Charger]
# 1           [Yoga Mat, Water Bottle, Protein Powder]
# ...

# %%
list(set(df['CustomerID'].tolist()))
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %%
customer_names = {
    'CustomerID' : list(set(df['CustomerID'].tolist())),
    'Name': ['Ghost', 'Arya', 'Jon', 'Eddard', 'Summer', 'Bran', 'Tyrion', 'Tywin' ]
}

df2 = pd.DataFrame(customer_names)
df2.head()
# Out:
#    CustomerID    Name
# 0         101   Ghost
# 1         102    Arya
# 2         103     Jon
# 3         104  Eddard
# 4         105  Summer

# %%
pd.merge(df, df2, on = ['CustomerID'])
# Out:
#     TransactionID  CustomerID                Item     Category  \
# 0               1         101          Phone Case  Electronics
# 1               1         101    Screen Protector  Electronics
# 2               1         101    Wireless Charger  Electronics
# 3               2         102            Yoga Mat      Fitness
# 4               2         102        Water Bottle      Fitness
# 5               2         102      Protein Powder      Fitness
# 6               3         103          Phone Case  Electronics
# 7               3         103          Headphones  Electronics
# 8               4         104    Wireless Charger  Electronics
# 9               4         104    Portable Speaker  Electronics
# 10              4         104      Travel Adapter  Electronics
# 11              5         105            Yoga Mat      Fitness
# 12              5         105    Resistance Bands      Fitness
# 13              6         106        Coffee Maker      Kitchen
# ...

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      21 non-null     int64
#  1   CustomerID         21 non-null     int64
#  2   Item               21 non-null     object
#  3   Category           21 non-null     object
#  4   PurchaseTimestamp  21 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 972.0+ bytes

# %%
df.dtypes
# Out:
# TransactionID         int64
# CustomerID            int64
# Item                 object
# Category             object
# PurchaseTimestamp    object
# dtype: object

# %%
pd.to_datetime(df['PurchaseTimestamp'])
# Out:
# pandas.core.series.Series

# %%
df['PurchaseTimestamp'] = pd.to_datetime(df['PurchaseTimestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      21 non-null     int64
#  1   CustomerID         21 non-null     int64
#  2   Item               21 non-null     object
#  3   Category           21 non-null     object
#  4   PurchaseTimestamp  21 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 972.0+ bytes

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#     PurchaseTimestamp  Cost
# 0 2025-01-01 10:05:00   160
# 1 2025-01-01 10:07:00    58
# 2 2025-01-01 10:10:00   257
# 3 2025-01-02 15:20:00   121
# 4 2025-01-02 15:25:00   271

# %%
df['date'] = df['PurchaseTimestamp'].dt.date
df['month'] = df['PurchaseTimestamp'].dt.month
df['year'] = df['PurchaseTimestamp'].dt.year

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#     PurchaseTimestamp  Cost        date  month  year
# 0 2025-01-01 10:05:00   160  2025-01-01      1  2025
# 1 2025-01-01 10:07:00    58  2025-01-01      1  2025
# 2 2025-01-01 10:10:00   257  2025-01-01      1  2025
# 3 2025-01-02 15:20:00   121  2025-01-02      1  2025
# 4 2025-01-02 15:25:00   271  2025-01-02      1  2025
